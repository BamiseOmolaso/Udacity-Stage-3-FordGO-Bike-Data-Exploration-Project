# %% [markdown]
# # Part II - (Fordgobike Data Exploration)
#
# ## by (Oluwabamise Omolaso)

# %% [markdown]
# ## Investigation Overview
#
#
# > The goal was to explore the dataset and understand the relationships between the variables in the data.
#
# - Key Insights for Presentation
#
# Relationship between duration and distance: this was chosen because there is an inverse relationship rather than a direct one. <br>
# Relationship between age with duration and distance - this was chosen because it was seen that there is an inverse relationship where duration travelled and distances covered decrease with increasing age <br>
# Distribution of trips by hour of day - the relationship here shows there are more rides during the weekdays over weekends <br>
# Distribution of trips by user_type, gender and age group -It is seen that the female and other gender tend to have higher average trip durations compared to the male gender and customers are also higher in average trip duration compared to subscribers. <br>
#
#
# ## Dataset Overview
#
# > The dataset contains data related to individual bike rides taken in a bike-sharing system that operates across the larger region of San Francisco Bay area in the year 2019 and spanned 1st of February to 1st of March.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the cleaned dataset into a pandas dataframe
ford = pd.read_csv('cleaned_ford.csv')

ford.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174879 entries, 0 to 174878
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             174879 non-null  int64
#  1   start_time               174879 non-null  object
#  2   end_time                 174879 non-null  object
#  3   start_station_id         174879 non-null  float64
#  4   start_station_name       174879 non-null  object
#  5   start_station_latitude   174879 non-null  float64
#  6   start_station_longitude  174879 non-null  float64
#  7   end_station_id           174879 non-null  float64
#  8   end_station_name         174879 non-null  object
#  9   end_station_latitude     174879 non-null  float64
#  10  end_station_longitude    174879 non-null  float64
#  11  bike_id                  174879 non-null  int64
#  12  user_type                174879 non-null  object
# ...

# %% [markdown]
# ## (Relationship between duration and distance)
#
# > Relationship between duration and distance: this was chosen because there is an inverse relationship rather than a direct one.

# %%
plt.figure(figsize=[8, 5])
plt.scatter(data=ford, x='duration_mins', y='distance_km')
plt.xlabel('duration_mins')
plt.ylabel('distance_km')
plt.title('Distance_km vs Duration_mins');

# %% [markdown]
# ## (Distribution of trips by hour of day)
#
# > Distribution of trips by hour of day - the relationship here shows there are more rides during the weekdays over weekends <br>

# %%
default_color = sb.color_palette()[0]
plt.figure(figsize=[10, 6])
sb.countplot(data = ford, x = 'hour_of_day', color = default_color)
plt.title('Trips by hour_of_day');

# %% [markdown]
# ## (Relationship between age with duration and distance)
#
# Relationship between age with duration and distance - this was chosen because it was seen that there is an inverse relationship where duration travelled and distances covered decrease with increasing age <br>

# %%
plt.figure(figsize = [20, 6]) 

default_color = sb.color_palette()[0]

plt.subplot(1, 2, 1) 
plt.scatter(x='age',y='duration_mins',data=ford, color = default_color)
plt.xlabel('age(years)')
plt.ylabel('duration(mins)')
plt.title('Duration(mins) travelled by age');


plt.subplot(1, 2, 2) 
sb.regplot('age',y='distance_km',data=ford, color = default_color)
plt.xlabel('age(years)')
plt.ylabel('distance_km)')
plt.title('Distance(km) travelled by age');

# %% [markdown]
# ## (Distribution of trips by user_type, gender and age group)
#
# Distribution of trips by user_type, gender and age group - It is seen that the female and other gender tend to have higher average trip durations compared to the male gender and customers also have higher average trip duration compared to subscribers. <br>

# %%
# create pivot table
duration_by_type_gender_age = ford.pivot_table(values='duration_mins', index='user_type', columns=['member_gender', 'age_group'], aggfunc=np.mean)

# create heatmap
plt.figure(figsize=[12,8])
sb.heatmap(duration_by_type_gender_age, cmap='coolwarm', cbar_kws={'label': 'Average Trip Duration (minutes)'},annot=True)
plt.title('Average trip duration (mins) by user type, gender, and age group')
plt.xlabel('Gender and Age Group')
plt.ylabel('User Type')
plt.show()

# %%
# !jupyter nbconvert Part_II_(Fordgobike_Data_Exploration).ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_(Fordgobike_Data_Exploration).ipynb to slides
# [NbConvertApp] Writing 713108 bytes to Part_II_(Fordgobike_Data_Exploration).slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\Scripts\jupyter-nbconvert-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\ProgramData\Anaconda3\lib\site-packages\jupyter_core\application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 346, in start
#     self.convert_notebooks()
# ...
